# %%
readfile="/users/成名/desktop/666/新建文件夹/day01/kaifangX.txt"
uritefile = "C:/Users/成名/Desktop/lalala.txt"
a=open(uritefile,'w',encoding='utf-8')
with open(readfile,"r",encoding="gbk",errors="ignore") as f:
    for i in range(10000):
        try:
            gender=f.readline().split("")[9]
            a.write(gender)
        except Exception as e:
            print(e)
            print("空白")
readfile.close()
a.close()
# Out:
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# empty separator
# 空白
# ...
